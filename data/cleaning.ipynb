# %%
import pandas as pd

# %%
df = pd.read_csv('apartments_20241212_222652.csv')

# %%
df.iloc[1]['address']
# Out:
# 'Przedmieście Świdnickie, Stare Miasto, Wrocław, dolnośląskie'

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.otodom.pl//pl/oferta/3-pokojowe-ja...
# 1  https://www.otodom.pl//pl/oferta/komfortowe-mi...
# 2  https://www.otodom.pl//pl/oferta/nowe-swiezo-p...
# 3  https://www.otodom.pl//pl/oferta/dwupokojowe-m...
# 4  https://www.otodom.pl//pl/oferta/bezposrednio-...
#
#                                                title     price  \
# 0          3-pokojowe jasne ciche koło WUM ENG/DE/RU  3 900 zł
# 1      Komfortowe mieszkanie w centrum - ul. Tęczowa  3 000 zł
# 2  Nowe, świeżo po remoncie 2 pokoje, ul. Łopusza...  3 499 zł
# 3  Dwupokojowe mieszkanie przy samym metrze WIERZ...  4 000 zł
# 4    Bezpośrednio W-wa Wola przy stacji metra Młynów  3 200 zł
#
#                                              address    m2   heating floor  \
# 0  ul. Drawska 10, Szczęśliwice, Ochota, Warszawa...  79m²  miejskie   3/4
# 1  Przedmieście Świdnickie, Stare Miasto, Wrocław...  47m²  miejskie   6/7
# ...
